# %% [markdown]
# <a href="https://colab.research.google.com/github/geethu-sebastian/ML/blob/main/Histograms.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# https://www.kdnuggets.com/2023/01/creating-beautiful-histograms-seaborn.html

# %%
import seaborn as sns

# %%
mpg = sns.load_dataset('mpg')
mpg.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
# Create a histogram of the "mpg" variable
sns.histplot(data=mpg, x="mpg")
# Out:
# <Axes: xlabel='mpg', ylabel='Count'>

# %%
sns.histplot(data=mpg, x="mpg", hue = 'origin')
# Out:
# <Axes: xlabel='mpg', ylabel='Count'>

# %%
sns.histplot(data=mpg, x="mpg",  kde=True)
# Out:
# <Axes: xlabel='mpg', ylabel='Count'>

# %%
sns.histplot(data=mpg, x="mpg",  bins = 5)
# Out:
# <Axes: xlabel='mpg', ylabel='Count'>

# %%
sns.histplot(data=mpg, x="mpg",  binwidth=5)
# Out:
# <Axes: xlabel='mpg', ylabel='Count'>

# %%
sns.histplot(data=mpg, x="mpg",  binrange=(5, 30))
# Out:
# <Axes: xlabel='mpg', ylabel='Count'>

# %%
sns.histplot(data=mpg, x="mpg", stat = 'frequency')
# Out:
# <Axes: xlabel='mpg', ylabel='Frequency'>

# %%
sns.histplot(data=mpg, x="mpg", stat = 'probability')
# Out:
# <Axes: xlabel='mpg', ylabel='Probability'>

# %%
sns.histplot(data=mpg, x="mpg", stat = 'density')
# Out:
# <Axes: xlabel='mpg', ylabel='Density'>

# %%
sns.histplot(data=mpg, x="mpg",  color = 'red', alpha = 0.5)
# Out:
# <Axes: xlabel='mpg', ylabel='Count'>

# %%
sns.histplot(data=mpg, x="mpg", kde = True, palette = "Spectral", hue ='origin')
# Out:
# <Axes: xlabel='mpg', ylabel='Count'>

# %% [markdown]
# Exploring Heights Dataset

# %%
# import necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# obtain dataset
df = pd.read_csv('https://raw.githubusercontent.com/bot13956/Bayes_theorem/master/heights.csv')

# display head of dataset
df.head()
# Out:
#     sex  height
# 0  Male    75.0
# 1  Male    70.0
# 2  Male    68.0
# 3  Male    74.0
# 4  Male    61.0

# %%
sns.histplot(data = df, x="height")
# Out:
# <Axes: xlabel='height', ylabel='Count'>

# %%
sns.histplot(data=df, x="height", hue="sex")
# Out:
# <Axes: xlabel='height', ylabel='Count'>

# %%
sns.histplot(data = df[df.sex=='Male']['height'], color='blue')
# Out:
# <Axes: xlabel='height', ylabel='Count'>

# %%
sns.histplot(data = df[df.sex=='Female']['height'], color='orange')
# Out:
# <Axes: xlabel='height', ylabel='Count'>
